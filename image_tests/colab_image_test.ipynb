# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install qiskit qiskit-aer-gpu matplotlib pillow numpy

# %%
import os
os.chdir('/content/drive/MyDrive/Quantum_Bilinear')
# Verify files are visible
# !ls
# Out:
# 1_5_main_google_colab.py  colab_image_test.ipynb
# 2_basic_gates.py	  image_downscaler.py
# 3_circuit_gates.py	  image_processing.py
# 4_circuit_methods.py	  Lenna_input_24.tif
# 5_classical_BLI_check.py  Original_1_Lenna_64_grey.tif
# 6_neqr_encoding.py	  __pycache__

# %%
from qiskit_aer import AerSimulator
print("Import Successful! AerSimulator is ready.")
# Out:
# Import Successful! AerSimulator is ready.

# %%
# 1. Uninstall existing conflicting versions
# !pip uninstall -y qiskit qiskit-aer qiskit-aer-gpu

# 2. Install the latest stable 1.x versions
# qiskit-aer now includes GPU support by default in many cases, 
# but we install the unified package.
# !pip install qiskit qiskit-aer
# Out:
# Found existing installation: qiskit 2.5.0
# Uninstalling qiskit-2.5.0:
#   Successfully uninstalled qiskit-2.5.0
# WARNING: Skipping qiskit-aer as it is not installed.
# Found existing installation: qiskit-aer-gpu 0.15.1
# Uninstalling qiskit-aer-gpu-0.15.1:
#   Successfully uninstalled qiskit-aer-gpu-0.15.1
# ...
#   Using cached qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# ...
# Using cached qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 114.9 MB/s eta 0:00:0000:010:01
# ...

# %%
# %run 1_5_main_google_colab.py
# Out:
# initial Image Shape: (24, 24)
